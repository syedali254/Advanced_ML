# %%
from imblearn.pipeline import Pipeline as ImbPipeline   # not sklearn!
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.datasets import make_classification

# %%
#1st step geenrate a dataset for class imbalanced
X,Y=make_classification(
    n_samples=100000,
    n_features=20,
    n_informative=10,
    weights=[0.99,0.01],
    random_state=42
)

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)

pipe=ImbPipeline([
    ('scaler',StandardScaler()),
    ('smote',SMOTE(k_neighbors=5,random_state=42)),
    ('clf',LogisticRegression(max_iter=1000))

])

score=cross_val_score(pipe,
                      X_train,Y_train,
                      cv=StratifiedKFold(n_splits=5,shuffle=True,random_state=42),
                      scoring="accuracy")

print(score)
# Out:
# [0.75725   0.7649375 0.7585625 0.7679375 0.7609375]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 31
#      23 cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
#      25 # ── run cross-validation ──────────────────────────────────────────
#      26 # pass X_train, y_train — NOT the full X, y
#      27 # scoring='average_precision' = PR-AUC (your north star)
#      28 # n_jobs=-1 = use all CPU cores, runs folds in parallel
#      29 scores = cross_val_score(
#      30     pipe,
# ---> 31     X_train, y_train,
#      32     cv=cv,
#      33     scoring='average_precision',
#      34
#      35 )
#      37 # ── read the results ──────────────────────────────────────────────
#      38 print(f"Per fold : {scores.round(4)}")   # [0.61, 0.58, 0.63, ...]
#
# NameError: name 'y_train' is not defined
