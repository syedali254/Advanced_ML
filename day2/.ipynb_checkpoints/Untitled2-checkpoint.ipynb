# %%
from sklearn.datasets import make_classification
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
import numpy as np
from sklearn.model_selection import TimeSeriesSplit,cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
np.random.seed(42)
from sklearn.preprocessing import StandardScaler
X_raw, y = make_classification(
    n_samples=50_000, n_features=15, n_informative=6,
    weights=[0.98, 0.02], random_state=42
)
df = pd.DataFrame(X_raw, columns=[f'feat_{i}' for i in range(15)])
df['merchant_category'] = np.random.choice(['retail','travel','food','online'], len(df))
df['txn_timestamp'] = pd.date_range('2024-01-01', periods=len(df), freq='1min')
df['is_fraud'] = y

# INJECT a leaky feature
df['fraud_confirmed_flag'] = (y == 1).astype(float) + np.random.normal(0, 0.05, len(y))

df.sort_values('txn_timestamp').reset_index(drop=True)
X=df.drop(['is_fraud'],axis=1)

num_features=df.drop(columns=['merchant_category','txn_timestamp','is_fraud','fraud_confirmed_flag'],axis=1)

num_pipe=Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler()),

])

cat_features=df['merchant_category']
merchants=['food','online','retail','travel']
cat_pipeline=Pipeline([
    ('ordinal',OrdinalEncoder(categories=[merchants])),


    ])
print(cat_features.unique())

pre=

pipe=Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler()),


])
# Out:
# ['food' 'online' 'retail' 'travel']

# %%
print(df.head(4))
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0  1.036588  0.431236 -0.968821 -1.860261  2.116990 -0.591275 -0.334993
# 1  0.031483 -0.605536 -2.330207 -0.587372 -0.654416  1.705728 -1.503711
# 2  0.864832  0.458731 -2.368476 -2.053901  1.805993  0.870756  1.709916
# 3 -0.733713  1.088597 -0.337955 -2.345107  1.838905 -1.112428  0.719237
#
#      feat_7    feat_8    feat_9   feat_10   feat_11   feat_12   feat_13  \
# 0  0.353367  0.143270  2.101903  2.138486  0.785805 -0.307267 -1.123318
# 1 -1.386073  0.174560  0.745249 -3.758630 -1.964351  1.033345 -0.324187
# 2  1.490906 -0.327176  2.845561  1.674741  1.602274  0.850214 -1.277411
# 3 -0.888599 -0.098341  1.877729  3.293741 -0.747903 -0.175914 -0.491039
#
#     feat_14 merchant_category       txn_timestamp  is_fraud  \
# 0 -3.970424              food 2024-01-01 00:00:00         0
# 1  2.187229            online 2024-01-01 00:01:00         0
# 2 -4.561226            retail 2024-01-01 00:02:00         0
# 3 -4.187631              food 2024-01-01 00:03:00         0
#
#    fraud_confirmed_flag
# 0              0.020884
# 1              0.004668
# 2             -0.032971
# 3              0.000200
